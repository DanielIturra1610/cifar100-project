# %% [markdown]
# # Clasificación de CIFAR-100 en Clases y Superclases

# %% [markdown]
# ## Importación de Librerias

# %%
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D, concatenate
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar y preparación de datos

# %%
(x_train, y_train_fine), (x_test, y_test_fine) = cifar100.load_data(label_mode='fine')
(_, y_train_coarse), (_, y_test_coarse) = cifar100.load_data(label_mode='coarse')

# %% [markdown]
# ## Trata de Datos

# %% [markdown]
# ### Normalización de imagenes

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %% [markdown]
# ### Conversión de etiquetas a codificación one-hot

# %%
y_train_fine = to_categorical(y_train_fine, 100)
y_test_fine = to_categorical(y_test_fine, 100)
y_train_coarse = to_categorical(y_train_coarse, 20)
y_test_coarse = to_categorical(y_test_coarse, 20)

# %% [markdown]
# ### División en entrenamiento y validación

# %%
x_train_split, x_val_split, y_train_fine_split, y_val_fine_split, y_train_coarse_split, y_val_coarse_split = train_test_split(
    x_train, y_train_fine, y_train_coarse, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Generador para manejar ambas etiquetas

# %%
class MultiOutputDataGenerator(Sequence):
    def __init__(self, x, y_fine, y_coarse, datagen, batch_size=32, shuffle=True):
        self.x = x
        self.y_fine = y_fine
        self.y_coarse = y_coarse
        self.datagen = datagen
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(x))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.x) / self.batch_size))

    def __getitem__(self, index):
        batch_indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_x = self.x[batch_indexes]
        batch_y_fine = self.y_fine[batch_indexes]
        batch_y_coarse = self.y_coarse[batch_indexes]
        
        # Aplicar aumentación de datos
        augmented_x = np.zeros_like(batch_x)
        for i in range(len(batch_x)):
            augmented_x[i] = self.datagen.random_transform(batch_x[i])
        
        return augmented_x, {'fine_output': batch_y_fine, 'coarse_output': batch_y_coarse}

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# ### Aumentación de datos

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)

# %% [markdown]
# ### Algo raro

# %%
val_datagen = ImageDataGenerator()

batch_size = 64

# Crear generadores
train_generator = MultiOutputDataGenerator(
    x_train_split,
    y_train_fine_split,
    y_train_coarse_split,
    train_datagen,
    batch_size=batch_size
)

val_generator = MultiOutputDataGenerator(
    x_val_split,
    y_val_fine_split,
    y_val_coarse_split,
    val_datagen,
    batch_size=batch_size
)

# Calcular steps
train_steps = len(train_generator)
val_steps = len(val_generator)

# %% [markdown]
# ## Arquitectura del modelo

# %% [markdown]
# ### Construcción del modelo CNN con multiples salidas

# %%
def build_model():
    input_layer = Input(shape=(32, 32, 3))
    
    # Bloque 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
    x = BatchNormalization()(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)
    
    # Bloque 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    
    # Bloque 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.5)(x)
    
    # Capas finales compartidas
    x = GlobalAveragePooling2D()(x)
    
    # Rama para clasificación fina (100 clases)
    fine = Dense(512, activation='relu')(x)
    fine = Dropout(0.5)(fine)
    fine_output = Dense(100, activation='softmax', name='fine_output')(fine)
    
    # Rama para superclases (20 categorías)
    coarse = Dense(256, activation='relu')(x)
    coarse = Dropout(0.4)(coarse)
    coarse_output = Dense(20, activation='softmax', name='coarse_output')(coarse)
    
    model = Model(inputs=input_layer, outputs=[fine_output, coarse_output])
    
    return model

model = build_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)           1792      ['input_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           36928     ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 32, 32, 64)           256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 64)           0         ['batch_normalization_7[0][0]'
#  g2D)                                                               ]
#
#  dropout_5 (Dropout)         (None, 16, 16, 64)           0         ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)          73856     ['dropout_5[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)          147584    ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 16, 16, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 128)            0         ['batch_normalization_9[0][0]'
#  g2D)                                                               ]
#
#  dropout_6 (Dropout)         (None, 8, 8, 128)            0         ['max_pooling2d_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)            295168    ['dropout_6[0][0]']
#
#  batch_normalization_10 (Ba  (None, 8, 8, 256)            1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 256)            590080    ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 8, 8, 256)            1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 256)            0         ['batch_normalization_11[0][0]
#  g2D)                                                               ']
#
#  dropout_7 (Dropout)         (None, 4, 4, 256)            0         ['max_pooling2d_5[0][0]']
#
#  global_average_pooling2d_1  (None, 256)                  0         ['dropout_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 512)                  131584    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 256)                  65792     ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dropout_8 (Dropout)         (None, 512)                  0         ['dense_2[0][0]']
#
#  dropout_9 (Dropout)         (None, 256)                  0         ['dense_3[0][0]']
#
#  fine_output (Dense)         (None, 100)                  51300     ['dropout_8[0][0]']
#
#  coarse_output (Dense)       (None, 20)                   5140      ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 1402808 (5.35 MB)
# Trainable params: 1401016 (5.34 MB)
# Non-trainable params: 1792 (7.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Compilación del modelo

# %%
optimizer = SGD(learning_rate=1e-3, momentum=0.9, nesterov=True)
model.compile(
    optimizer=optimizer,
    loss={
        'fine_output': 'categorical_crossentropy',
        'coarse_output': 'categorical_crossentropy'
    },
    metrics={
        'fine_output': 'accuracy',
        'coarse_output': 'accuracy'
    },
    loss_weights={
        'fine_output': 1.0,  # Más peso en la clasificación fina
        'coarse_output': 0.5  # Menos peso en las superclases
    }
)

# %% [markdown]
# ### Callbacks para entrenamiento

# %%
early_stop = EarlyStopping(
    monitor='val_fine_output_accuracy',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint_cb = ModelCheckpoint(
    filepath='checkpoints/cnn_cifar100_multioutput_best.h5',
    monitor='val_fine_output_accuracy',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_fine_output_accuracy',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# %% [markdown]
# ## Entrenamiento del Modelo

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_steps,
    epochs=100,
    validation_data=val_generator,
    validation_steps=val_steps,
    callbacks=[early_stop, checkpoint_cb, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 625/625 [==============================] - ETA: 0s - loss: 5.0228 - fine_output_loss: 3.8090 - coarse_output_loss: 2.4276 - fine_output_accuracy: 0.1075 - coarse_output_accuracy: 0.2462
# Epoch 1: val_fine_output_accuracy improved from -inf to 0.13920, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# /usr/local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 625/625 [==============================] - 201s 319ms/step - loss: 5.0228 - fine_output_loss: 3.8090 - coarse_output_loss: 2.4276 - fine_output_accuracy: 0.1075 - coarse_output_accuracy: 0.2462 - val_loss: 4.7918 - val_fine_output_loss: 3.6283 - val_coarse_output_loss: 2.3269 - val_fine_output_accuracy: 0.1392 - val_coarse_output_accuracy: 0.2720 - lr: 0.0010
# Epoch 2/100
# 625/625 [==============================] - ETA: 0s - loss: 4.8843 - fine_output_loss: 3.7029 - coarse_output_loss: 2.3629 - fine_output_accuracy: 0.1226 - coarse_output_accuracy: 0.2649
# Epoch 2: val_fine_output_accuracy improved from 0.13920 to 0.16340, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 224s 358ms/step - loss: 4.8843 - fine_output_loss: 3.7029 - coarse_output_loss: 2.3629 - fine_output_accuracy: 0.1226 - coarse_output_accuracy: 0.2649 - val_loss: 4.6021 - val_fine_output_loss: 3.4885 - val_coarse_output_loss: 2.2271 - val_fine_output_accuracy: 0.1634 - val_coarse_output_accuracy: 0.3001 - lr: 0.0010
# Epoch 3/100
# 625/625 [==============================] - ETA: 0s - loss: 4.7661 - fine_output_loss: 3.6140 - coarse_output_loss: 2.3041 - fine_output_accuracy: 0.1397 - coarse_output_accuracy: 0.2837
# Epoch 3: val_fine_output_accuracy improved from 0.16340 to 0.16970, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 222s 355ms/step - loss: 4.7661 - fine_output_loss: 3.6140 - coarse_output_loss: 2.3041 - fine_output_accuracy: 0.1397 - coarse_output_accuracy: 0.2837 - val_loss: 4.5701 - val_fine_output_loss: 3.4632 - val_coarse_output_loss: 2.2138 - val_fine_output_accuracy: 0.1697 - val_coarse_output_accuracy: 0.3005 - lr: 0.0010
# Epoch 4/100
# 625/625 [==============================] - ETA: 0s - loss: 4.6583 - fine_output_loss: 3.5303 - coarse_output_loss: 2.2560 - fine_output_accuracy: 0.1519 - coarse_output_accuracy: 0.3015
# Epoch 4: val_fine_output_accuracy improved from 0.16970 to 0.18660, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 213s 341ms/step - loss: 4.6583 - fine_output_loss: 3.5303 - coarse_output_loss: 2.2560 - fine_output_accuracy: 0.1519 - coarse_output_accuracy: 0.3015 - val_loss: 4.3779 - val_fine_output_loss: 3.3185 - val_coarse_output_loss: 2.1189 - val_fine_output_accuracy: 0.1866 - val_coarse_output_accuracy: 0.3286 - lr: 0.0010
# Epoch 5/100
# 625/625 [==============================] - ETA: 0s - loss: 4.5478 - fine_output_loss: 3.4467 - coarse_output_loss: 2.2022 - fine_output_accuracy: 0.1680 - coarse_output_accuracy: 0.3122
# Epoch 5: val_fine_output_accuracy improved from 0.18660 to 0.19610, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 207s 331ms/step - loss: 4.5478 - fine_output_loss: 3.4467 - coarse_output_loss: 2.2022 - fine_output_accuracy: 0.1680 - coarse_output_accuracy: 0.3122 - val_loss: 4.3385 - val_fine_output_loss: 3.2942 - val_coarse_output_loss: 2.0886 - val_fine_output_accuracy: 0.1961 - val_coarse_output_accuracy: 0.3473 - lr: 0.0010
# Epoch 6/100
# 625/625 [==============================] - ETA: 0s - loss: 4.4390 - fine_output_loss: 3.3663 - coarse_output_loss: 2.1454 - fine_output_accuracy: 0.1834 - coarse_output_accuracy: 0.3324
# Epoch 6: val_fine_output_accuracy did not improve from 0.19610
# 625/625 [==============================] - 214s 343ms/step - loss: 4.4390 - fine_output_loss: 3.3663 - coarse_output_loss: 2.1454 - fine_output_accuracy: 0.1834 - coarse_output_accuracy: 0.3324 - val_loss: 4.3812 - val_fine_output_loss: 3.3281 - val_coarse_output_loss: 2.1064 - val_fine_output_accuracy: 0.1836 - val_coarse_output_accuracy: 0.3336 - lr: 0.0010
# Epoch 7/100
# 625/625 [==============================] - ETA: 0s - loss: 4.3312 - fine_output_loss: 3.2869 - coarse_output_loss: 2.0887 - fine_output_accuracy: 0.1944 - coarse_output_accuracy: 0.3453
# Epoch 7: val_fine_output_accuracy improved from 0.19610 to 0.22500, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 217s 347ms/step - loss: 4.3312 - fine_output_loss: 3.2869 - coarse_output_loss: 2.0887 - fine_output_accuracy: 0.1944 - coarse_output_accuracy: 0.3453 - val_loss: 4.1261 - val_fine_output_loss: 3.1249 - val_coarse_output_loss: 2.0023 - val_fine_output_accuracy: 0.2250 - val_coarse_output_accuracy: 0.3716 - lr: 0.0010
# Epoch 8/100
# 625/625 [==============================] - ETA: 0s - loss: 4.2282 - fine_output_loss: 3.2080 - coarse_output_loss: 2.0404 - fine_output_accuracy: 0.2077 - coarse_output_accuracy: 0.3616
# Epoch 8: val_fine_output_accuracy improved from 0.22500 to 0.22780, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 235s 376ms/step - loss: 4.2282 - fine_output_loss: 3.2080 - coarse_output_loss: 2.0404 - fine_output_accuracy: 0.2077 - coarse_output_accuracy: 0.3616 - val_loss: 4.1239 - val_fine_output_loss: 3.1268 - val_coarse_output_loss: 1.9941 - val_fine_output_accuracy: 0.2278 - val_coarse_output_accuracy: 0.3746 - lr: 0.0010
# Epoch 9/100
# 625/625 [==============================] - ETA: 0s - loss: 4.1448 - fine_output_loss: 3.1461 - coarse_output_loss: 1.9975 - fine_output_accuracy: 0.2159 - coarse_output_accuracy: 0.3696
# Epoch 9: val_fine_output_accuracy did not improve from 0.22780
# 625/625 [==============================] - 263s 420ms/step - loss: 4.1448 - fine_output_loss: 3.1461 - coarse_output_loss: 1.9975 - fine_output_accuracy: 0.2159 - coarse_output_accuracy: 0.3696 - val_loss: 4.2285 - val_fine_output_loss: 3.2106 - val_coarse_output_loss: 2.0358 - val_fine_output_accuracy: 0.2081 - val_coarse_output_accuracy: 0.3637 - lr: 0.0010
# Epoch 10/100
# 625/625 [==============================] - ETA: 0s - loss: 4.0511 - fine_output_loss: 3.0730 - coarse_output_loss: 1.9563 - fine_output_accuracy: 0.2298 - coarse_output_accuracy: 0.3832
# Epoch 10: val_fine_output_accuracy improved from 0.22780 to 0.24250, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 264s 422ms/step - loss: 4.0511 - fine_output_loss: 3.0730 - coarse_output_loss: 1.9563 - fine_output_accuracy: 0.2298 - coarse_output_accuracy: 0.3832 - val_loss: 4.0299 - val_fine_output_loss: 3.0482 - val_coarse_output_loss: 1.9634 - val_fine_output_accuracy: 0.2425 - val_coarse_output_accuracy: 0.3935 - lr: 0.0010
# Epoch 11/100
# 625/625 [==============================] - ETA: 0s - loss: 3.9649 - fine_output_loss: 3.0080 - coarse_output_loss: 1.9137 - fine_output_accuracy: 0.2437 - coarse_output_accuracy: 0.3957
# Epoch 11: val_fine_output_accuracy improved from 0.24250 to 0.27690, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 264s 422ms/step - loss: 3.9649 - fine_output_loss: 3.0080 - coarse_output_loss: 1.9137 - fine_output_accuracy: 0.2437 - coarse_output_accuracy: 0.3957 - val_loss: 3.7555 - val_fine_output_loss: 2.8605 - val_coarse_output_loss: 1.7900 - val_fine_output_accuracy: 0.2769 - val_coarse_output_accuracy: 0.4356 - lr: 0.0010
# Epoch 12/100
# 625/625 [==============================] - ETA: 0s - loss: 3.8908 - fine_output_loss: 2.9525 - coarse_output_loss: 1.8766 - fine_output_accuracy: 0.2510 - coarse_output_accuracy: 0.4089
# Epoch 12: val_fine_output_accuracy did not improve from 0.27690
# 625/625 [==============================] - 261s 419ms/step - loss: 3.8908 - fine_output_loss: 2.9525 - coarse_output_loss: 1.8766 - fine_output_accuracy: 0.2510 - coarse_output_accuracy: 0.4089 - val_loss: 4.0015 - val_fine_output_loss: 3.0362 - val_coarse_output_loss: 1.9307 - val_fine_output_accuracy: 0.2451 - val_coarse_output_accuracy: 0.3979 - lr: 0.0010
# Epoch 13/100
# 625/625 [==============================] - ETA: 0s - loss: 3.8211 - fine_output_loss: 2.8996 - coarse_output_loss: 1.8430 - fine_output_accuracy: 0.2619 - coarse_output_accuracy: 0.4178
# Epoch 13: val_fine_output_accuracy did not improve from 0.27690
# 625/625 [==============================] - 262s 419ms/step - loss: 3.8211 - fine_output_loss: 2.8996 - coarse_output_loss: 1.8430 - fine_output_accuracy: 0.2619 - coarse_output_accuracy: 0.4178 - val_loss: 4.0081 - val_fine_output_loss: 3.0698 - val_coarse_output_loss: 1.8766 - val_fine_output_accuracy: 0.2394 - val_coarse_output_accuracy: 0.4060 - lr: 0.0010
# Epoch 14/100
# 625/625 [==============================] - ETA: 0s - loss: 3.7470 - fine_output_loss: 2.8442 - coarse_output_loss: 1.8057 - fine_output_accuracy: 0.2732 - coarse_output_accuracy: 0.4277
# Epoch 14: val_fine_output_accuracy did not improve from 0.27690
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 262s 419ms/step - loss: 3.7470 - fine_output_loss: 2.8442 - coarse_output_loss: 1.8057 - fine_output_accuracy: 0.2732 - coarse_output_accuracy: 0.4277 - val_loss: 3.7356 - val_fine_output_loss: 2.8465 - val_coarse_output_loss: 1.7782 - val_fine_output_accuracy: 0.2634 - val_coarse_output_accuracy: 0.4382 - lr: 0.0010
# Epoch 15/100
# 625/625 [==============================] - ETA: 0s - loss: 3.6545 - fine_output_loss: 2.7770 - coarse_output_loss: 1.7550 - fine_output_accuracy: 0.2857 - coarse_output_accuracy: 0.4429
# Epoch 15: val_fine_output_accuracy improved from 0.27690 to 0.30840, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 262s 419ms/step - loss: 3.6545 - fine_output_loss: 2.7770 - coarse_output_loss: 1.7550 - fine_output_accuracy: 0.2857 - coarse_output_accuracy: 0.4429 - val_loss: 3.4981 - val_fine_output_loss: 2.6712 - val_coarse_output_loss: 1.6536 - val_fine_output_accuracy: 0.3084 - val_coarse_output_accuracy: 0.4733 - lr: 5.0000e-04
# Epoch 16/100
# 625/625 [==============================] - ETA: 0s - loss: 3.6066 - fine_output_loss: 2.7399 - coarse_output_loss: 1.7333 - fine_output_accuracy: 0.2921 - coarse_output_accuracy: 0.4500
# Epoch 16: val_fine_output_accuracy did not improve from 0.30840
# 625/625 [==============================] - 264s 423ms/step - loss: 3.6066 - fine_output_loss: 2.7399 - coarse_output_loss: 1.7333 - fine_output_accuracy: 0.2921 - coarse_output_accuracy: 0.4500 - val_loss: 3.8368 - val_fine_output_loss: 2.9246 - val_coarse_output_loss: 1.8243 - val_fine_output_accuracy: 0.2714 - val_coarse_output_accuracy: 0.4325 - lr: 5.0000e-04
# Epoch 17/100
# 625/625 [==============================] - ETA: 0s - loss: 3.5803 - fine_output_loss: 2.7170 - coarse_output_loss: 1.7266 - fine_output_accuracy: 0.3014 - coarse_output_accuracy: 0.4539
# Epoch 17: val_fine_output_accuracy improved from 0.30840 to 0.31150, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 262s 420ms/step - loss: 3.5803 - fine_output_loss: 2.7170 - coarse_output_loss: 1.7266 - fine_output_accuracy: 0.3014 - coarse_output_accuracy: 0.4539 - val_loss: 3.4758 - val_fine_output_loss: 2.6561 - val_coarse_output_loss: 1.6393 - val_fine_output_accuracy: 0.3115 - val_coarse_output_accuracy: 0.4746 - lr: 5.0000e-04
# Epoch 18/100
# 625/625 [==============================] - ETA: 0s - loss: 3.5370 - fine_output_loss: 2.6867 - coarse_output_loss: 1.7006 - fine_output_accuracy: 0.2993 - coarse_output_accuracy: 0.4570
# Epoch 18: val_fine_output_accuracy improved from 0.31150 to 0.31530, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 264s 422ms/step - loss: 3.5370 - fine_output_loss: 2.6867 - coarse_output_loss: 1.7006 - fine_output_accuracy: 0.2993 - coarse_output_accuracy: 0.4570 - val_loss: 3.4716 - val_fine_output_loss: 2.6505 - val_coarse_output_loss: 1.6421 - val_fine_output_accuracy: 0.3153 - val_coarse_output_accuracy: 0.4770 - lr: 5.0000e-04
# Epoch 19/100
# 625/625 [==============================] - ETA: 0s - loss: 3.5172 - fine_output_loss: 2.6727 - coarse_output_loss: 1.6889 - fine_output_accuracy: 0.3048 - coarse_output_accuracy: 0.4624
# Epoch 19: val_fine_output_accuracy did not improve from 0.31530
# 625/625 [==============================] - 242s 387ms/step - loss: 3.5172 - fine_output_loss: 2.6727 - coarse_output_loss: 1.6889 - fine_output_accuracy: 0.3048 - coarse_output_accuracy: 0.4624 - val_loss: 3.4324 - val_fine_output_loss: 2.6295 - val_coarse_output_loss: 1.6059 - val_fine_output_accuracy: 0.3129 - val_coarse_output_accuracy: 0.4819 - lr: 5.0000e-04
# Epoch 20/100
# 625/625 [==============================] - ETA: 0s - loss: 3.4742 - fine_output_loss: 2.6394 - coarse_output_loss: 1.6696 - fine_output_accuracy: 0.3111 - coarse_output_accuracy: 0.4682
# Epoch 20: val_fine_output_accuracy did not improve from 0.31530
# 625/625 [==============================] - 218s 349ms/step - loss: 3.4742 - fine_output_loss: 2.6394 - coarse_output_loss: 1.6696 - fine_output_accuracy: 0.3111 - coarse_output_accuracy: 0.4682 - val_loss: 3.5211 - val_fine_output_loss: 2.6904 - val_coarse_output_loss: 1.6615 - val_fine_output_accuracy: 0.3108 - val_coarse_output_accuracy: 0.4749 - lr: 5.0000e-04
# Epoch 21/100
# 625/625 [==============================] - ETA: 0s - loss: 3.4484 - fine_output_loss: 2.6206 - coarse_output_loss: 1.6555 - fine_output_accuracy: 0.3168 - coarse_output_accuracy: 0.4720
# Epoch 21: val_fine_output_accuracy improved from 0.31530 to 0.34670, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 217s 347ms/step - loss: 3.4484 - fine_output_loss: 2.6206 - coarse_output_loss: 1.6555 - fine_output_accuracy: 0.3168 - coarse_output_accuracy: 0.4720 - val_loss: 3.2819 - val_fine_output_loss: 2.4953 - val_coarse_output_loss: 1.5733 - val_fine_output_accuracy: 0.3467 - val_coarse_output_accuracy: 0.5018 - lr: 5.0000e-04
# Epoch 22/100
# 625/625 [==============================] - ETA: 0s - loss: 3.4057 - fine_output_loss: 2.5837 - coarse_output_loss: 1.6439 - fine_output_accuracy: 0.3241 - coarse_output_accuracy: 0.4762
# Epoch 22: val_fine_output_accuracy did not improve from 0.34670
# 625/625 [==============================] - 217s 348ms/step - loss: 3.4057 - fine_output_loss: 2.5837 - coarse_output_loss: 1.6439 - fine_output_accuracy: 0.3241 - coarse_output_accuracy: 0.4762 - val_loss: 3.3589 - val_fine_output_loss: 2.5662 - val_coarse_output_loss: 1.5853 - val_fine_output_accuracy: 0.3281 - val_coarse_output_accuracy: 0.4955 - lr: 5.0000e-04
# Epoch 23/100
# 625/625 [==============================] - ETA: 0s - loss: 3.3856 - fine_output_loss: 2.5722 - coarse_output_loss: 1.6269 - fine_output_accuracy: 0.3252 - coarse_output_accuracy: 0.4805
# Epoch 23: val_fine_output_accuracy did not improve from 0.34670
# 625/625 [==============================] - 221s 353ms/step - loss: 3.3856 - fine_output_loss: 2.5722 - coarse_output_loss: 1.6269 - fine_output_accuracy: 0.3252 - coarse_output_accuracy: 0.4805 - val_loss: 3.3833 - val_fine_output_loss: 2.5897 - val_coarse_output_loss: 1.5872 - val_fine_output_accuracy: 0.3262 - val_coarse_output_accuracy: 0.4962 - lr: 5.0000e-04
# Epoch 24/100
# 625/625 [==============================] - ETA: 0s - loss: 3.3530 - fine_output_loss: 2.5482 - coarse_output_loss: 1.6098 - fine_output_accuracy: 0.3297 - coarse_output_accuracy: 0.4882
# Epoch 24: val_fine_output_accuracy did not improve from 0.34670
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 [==============================] - 223s 356ms/step - loss: 3.3530 - fine_output_loss: 2.5482 - coarse_output_loss: 1.6098 - fine_output_accuracy: 0.3297 - coarse_output_accuracy: 0.4882 - val_loss: 3.5602 - val_fine_output_loss: 2.7378 - val_coarse_output_loss: 1.6448 - val_fine_output_accuracy: 0.3033 - val_coarse_output_accuracy: 0.4833 - lr: 5.0000e-04
# Epoch 25/100
# 625/625 [==============================] - ETA: 0s - loss: 3.3006 - fine_output_loss: 2.5079 - coarse_output_loss: 1.5854 - fine_output_accuracy: 0.3390 - coarse_output_accuracy: 0.4952
# Epoch 25: val_fine_output_accuracy improved from 0.34670 to 0.34990, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 217s 348ms/step - loss: 3.3006 - fine_output_loss: 2.5079 - coarse_output_loss: 1.5854 - fine_output_accuracy: 0.3390 - coarse_output_accuracy: 0.4952 - val_loss: 3.2046 - val_fine_output_loss: 2.4551 - val_coarse_output_loss: 1.4991 - val_fine_output_accuracy: 0.3499 - val_coarse_output_accuracy: 0.5226 - lr: 2.5000e-04
# Epoch 26/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2791 - fine_output_loss: 2.4914 - coarse_output_loss: 1.5754 - fine_output_accuracy: 0.3423 - coarse_output_accuracy: 0.4975
# Epoch 26: val_fine_output_accuracy improved from 0.34990 to 0.36730, saving model to checkpoints/cnn_cifar100_multioutput_best.h5
# 625/625 [==============================] - 218s 349ms/step - loss: 3.2791 - fine_output_loss: 2.4914 - coarse_output_loss: 1.5754 - fine_output_accuracy: 0.3423 - coarse_output_accuracy: 0.4975 - val_loss: 3.0866 - val_fine_output_loss: 2.3612 - val_coarse_output_loss: 1.4509 - val_fine_output_accuracy: 0.3673 - val_coarse_output_accuracy: 0.5323 - lr: 2.5000e-04
# Epoch 27/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2649 - fine_output_loss: 2.4818 - coarse_output_loss: 1.5662 - fine_output_accuracy: 0.3449 - coarse_output_accuracy: 0.5014
# Epoch 27: val_fine_output_accuracy did not improve from 0.36730
# 625/625 [==============================] - 214s 342ms/step - loss: 3.2649 - fine_output_loss: 2.4818 - coarse_output_loss: 1.5662 - fine_output_accuracy: 0.3449 - coarse_output_accuracy: 0.5014 - val_loss: 3.1509 - val_fine_output_loss: 2.4078 - val_coarse_output_loss: 1.4861 - val_fine_output_accuracy: 0.3625 - val_coarse_output_accuracy: 0.5262 - lr: 2.5000e-04
# Epoch 28/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2539 - fine_output_loss: 2.4728 - coarse_output_loss: 1.5622 - fine_output_accuracy: 0.3437 - coarse_output_accuracy: 0.4996
# Epoch 28: val_fine_output_accuracy did not improve from 0.36730
# 625/625 [==============================] - 216s 345ms/step - loss: 3.2539 - fine_output_loss: 2.4728 - coarse_output_loss: 1.5622 - fine_output_accuracy: 0.3437 - coarse_output_accuracy: 0.4996 - val_loss: 3.1118 - val_fine_output_loss: 2.3833 - val_coarse_output_loss: 1.4569 - val_fine_output_accuracy: 0.3660 - val_coarse_output_accuracy: 0.5325 - lr: 2.5000e-04
# Epoch 29/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2374 - fine_output_loss: 2.4618 - coarse_output_loss: 1.5512 - fine_output_accuracy: 0.3479 - coarse_output_accuracy: 0.5060
# Epoch 29: val_fine_output_accuracy did not improve from 0.36730
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 [==============================] - 215s 344ms/step - loss: 3.2374 - fine_output_loss: 2.4618 - coarse_output_loss: 1.5512 - fine_output_accuracy: 0.3479 - coarse_output_accuracy: 0.5060 - val_loss: 3.2419 - val_fine_output_loss: 2.4857 - val_coarse_output_loss: 1.5125 - val_fine_output_accuracy: 0.3485 - val_coarse_output_accuracy: 0.5179 - lr: 2.5000e-04
# Epoch 30/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2215 - fine_output_loss: 2.4480 - coarse_output_loss: 1.5470 - fine_output_accuracy: 0.3532 - coarse_output_accuracy: 0.5080
# Epoch 30: val_fine_output_accuracy did not improve from 0.36730
# 625/625 [==============================] - 256s 409ms/step - loss: 3.2215 - fine_output_loss: 2.4480 - coarse_output_loss: 1.5470 - fine_output_accuracy: 0.3532 - coarse_output_accuracy: 0.5080 - val_loss: 3.1655 - val_fine_output_loss: 2.4260 - val_coarse_output_loss: 1.4790 - val_fine_output_accuracy: 0.3609 - val_coarse_output_accuracy: 0.5268 - lr: 1.2500e-04
# Epoch 31/100
# 625/625 [==============================] - ETA: 0s - loss: 3.1885 - fine_output_loss: 2.4235 - coarse_output_loss: 1.5299 - fine_output_accuracy: 0.3563 - coarse_output_accuracy: 0.5118Restoring model weights from the end of the best epoch: 26.
#
# Epoch 31: val_fine_output_accuracy did not improve from 0.36730
# 625/625 [==============================] - 298s 477ms/step - loss: 3.1885 - fine_output_loss: 2.4235 - coarse_output_loss: 1.5299 - fine_output_accuracy: 0.3563 - coarse_output_accuracy: 0.5118 - val_loss: 3.1566 - val_fine_output_loss: 2.4205 - val_coarse_output_loss: 1.4722 - val_fine_output_accuracy: 0.3602 - val_coarse_output_accuracy: 0.5303 - lr: 1.2500e-04
# Epoch 31: early stopping

# %% [markdown]
# ### Evaluación y predicción

# %%
test_results = model.evaluate(
    x_test,
    {'fine_output': y_test_fine, 'coarse_output': y_test_coarse},
    verbose=1
)

print("\nResultados en el conjunto de prueba:")
print(f"Pérdida total: {test_results[0]}")
print(f"Pérdida clases finas: {test_results[1]}")
print(f"Pérdida superclases: {test_results[2]}")
print(f"Precisión clases finas: {test_results[3]}")
print(f"Precisión superclases: {test_results[4]}")

## Visualización de resultados
def plot_history(history):
    plt.figure(figsize=(12, 4))
    
    # Precisión
    plt.subplot(1, 2, 1)
    plt.plot(history.history['fine_output_accuracy'], label='Entrenamiento (clases)')
    plt.plot(history.history['val_fine_output_accuracy'], label='Validación (clases)')
    plt.plot(history.history['coarse_output_accuracy'], label='Entrenamiento (superclases)')
    plt.plot(history.history['val_coarse_output_accuracy'], label='Validación (superclases)')
    plt.title('Precisión durante el entrenamiento')
    plt.xlabel('Época')
    plt.ylabel('Precisión')
    plt.legend()
    
    # Pérdida
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Entrenamiento (total)')
    plt.plot(history.history['val_loss'], label='Validación (total)')
    plt.plot(history.history['fine_output_loss'], label='Entrenamiento (clases)')
    plt.plot(history.history['val_fine_output_loss'], label='Validación (clases)')
    plt.title('Pérdida durante el entrenamiento')
    plt.xlabel('Época')
    plt.ylabel('Pérdida')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

plot_history(history)

## Función para mostrar predicciones
def show_predictions(model, x, y_fine, y_coarse, num_samples=5):
    # Obtener predicciones
    fine_pred, coarse_pred = model.predict(x[:num_samples])
    
    # Convertir one-hot a índices
    fine_true = np.argmax(y_fine[:num_samples], axis=1)
    coarse_true = np.argmax(y_coarse[:num_samples], axis=1)
    fine_pred_idx = np.argmax(fine_pred, axis=1)
    coarse_pred_idx = np.argmax(coarse_pred, axis=1)
    
    plt.figure(figsize=(15, 5))
    for i in range(num_samples):
        plt.subplot(1, num_samples, i+1)
        plt.imshow(x[i])
        plt.title(f"Clase real: {fine_true[i]}\nPred: {fine_pred_idx[i]}\n"
                 f"Superclase real: {coarse_true[i]}\nPred: {coarse_pred_idx[i]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Mostrar algunas predicciones
show_predictions(model, x_test, y_test_fine, y_test_coarse)
# Out:
# 313/313 [==============================] - 17s 54ms/step - loss: 3.1024 - fine_output_loss: 2.3682 - coarse_output_loss: 1.4684 - fine_output_accuracy: 0.3694 - coarse_output_accuracy: 0.5288
#
# Resultados en el conjunto de prueba:
# Pérdida total: 3.102412462234497
# Pérdida clases finas: 2.368234872817993
# Pérdida superclases: 1.4683549404144287
# Precisión clases finas: 0.3693999946117401
# Precisión superclases: 0.5288000106811523
# 1/1 [==============================] - 0s 192ms/step
